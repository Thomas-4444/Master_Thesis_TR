# %%
# Import required Python packages and modules
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import random
# Set the random seed
seed = 44
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# # Refugee data prep

# %%
# Reading refugee origin df
ref_origin_location = pd.read_csv('refugee_population_origin_updated.csv')
ref_origin_location
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1979
# 1     Afghanistan  AFG  1980
# 2     Afghanistan  AFG  1981
# 3     Afghanistan  AFG  1982
# 4     Afghanistan  AFG  1983
# ...           ...  ...   ...
# 7090     Zimbabwe  ZWE  2018
# 7091     Zimbabwe  ZWE  2019
# 7092     Zimbabwe  ZWE  2020
# 7093     Zimbabwe  ZWE  2021
# 7094     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of origin
# 0                                                500000
# 1                                               1734921
# 2                                               3879984
# 3                                               4488214
# 4                                               4712735
# ...                                                 ...
# 7090                                              15618
# 7091                                              10045
# 7092                                               8575
# 7093                                               8115
# 7094                                               7008
#
# [7095 rows x 4 columns]

# %% [markdown]
# Checking properties of dataframe.

# %%
ref_origin_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7095 entries, 0 to 7094
# Data columns (total 4 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                7095 non-null   object
#  1   Code                                                  6667 non-null   object
#  2   Year                                                  7095 non-null   int64
#  3   Refugee population by country or territory of origin  7095 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 221.8+ KB

# %%
ref_origin_location.describe()
# Out:
#               Year  Refugee population by country or territory of origin
# count  7095.000000                                       7.095000e+03
# mean   2002.919521                                       3.125764e+05
# std      13.179365                                       1.638159e+06
# min    1960.000000                                       5.000000e+00
# 25%    1995.000000                                       9.800000e+01
# 50%    2005.000000                                       1.535000e+03
# 75%    2014.000000                                       3.369950e+04
# max    2022.000000                                       3.530039e+07

# %%
ref_origin_location.isnull().any()
# Out:
# Entity                                                  False
# Code                                                     True
# Year                                                    False
# Refugee population by country or territory of origin    False
# dtype: bool

# %% [markdown]
# Loading in other dataframe.

# %%
# Reading refugee destination df
ref_destination_location = pd.read_csv('refugee_population_destination_updated.csv')
ref_destination_location
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 7395     Zimbabwe  ZWE  2018
# 7396     Zimbabwe  ZWE  2019
# 7397     Zimbabwe  ZWE  2020
# 7398     Zimbabwe  ZWE  2021
# 7399     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of asylum
# 0                                                    50
# 1                                                    38
# 2                                                 60025
# 3                                                 32131
# 4                                                 19134
# ...                                                 ...
# 7395                                               7795
# 7396                                               8956
# 7397                                               9261
# 7398                                               9483
# 7399                                              10475
#
# [7400 rows x 4 columns]

# %%
ref_destination_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7400 entries, 0 to 7399
# Data columns (total 4 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                7400 non-null   object
#  1   Code                                                  6971 non-null   object
#  2   Year                                                  7400 non-null   int64
#  3   Refugee population by country or territory of asylum  7400 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 231.4+ KB

# %%
ref_origin_location.describe()
# Out:
#               Year  Refugee population by country or territory of origin
# count  7095.000000                                       7.095000e+03
# mean   2002.919521                                       3.125764e+05
# std      13.179365                                       1.638159e+06
# min    1960.000000                                       5.000000e+00
# 25%    1995.000000                                       9.800000e+01
# 50%    2005.000000                                       1.535000e+03
# 75%    2014.000000                                       3.369950e+04
# max    2022.000000                                       3.530039e+07

# %%
ref_destination_location.isnull().any()
# Out:
# Entity                                                  False
# Code                                                     True
# Year                                                    False
# Refugee population by country or territory of asylum    False
# dtype: bool

# %%
# Countries in ref_destination_location but not in ref_origin_location
countries_only_in_ref_destination = ref_destination_location[~ref_destination_location['Entity'].isin(ref_origin_location['Entity'])]['Entity']

print("Countries only in ref_destination_location:")
print(countries_only_in_ref_destination)
# Out:
# Countries only in ref_destination_location:
# 4252         Micronesia (country)
# 4253         Micronesia (country)
# 5786    Sint Maarten (Dutch part)
# 5787    Sint Maarten (Dutch part)
# 5788    Sint Maarten (Dutch part)
# 5789    Sint Maarten (Dutch part)
# 5790    Sint Maarten (Dutch part)
# 5791    Sint Maarten (Dutch part)
# 5792    Sint Maarten (Dutch part)
# 5793    Sint Maarten (Dutch part)
# 5794    Sint Maarten (Dutch part)
# Name: Entity, dtype: object

# %%
len(countries_only_in_ref_destination)
# Out:
# 11

# %%
len(countries_only_in_ref_destination.unique())
# Out:
# 2

# %%
ref_destination_location[ref_destination_location.Entity == 'Micronesia (country)']
# Out:
#                     Entity Code  Year  \
# 4252  Micronesia (country)  FSM  2015
# 4253  Micronesia (country)  FSM  2016
#
#       Refugee population by country or territory of asylum
# 4252                                                  5
# 4253                                                  5

# %%
# Countries in ref_origin_destination_location but not in ref_destination_location
countries_only_in_origin_destination = ref_origin_location[~ref_origin_location['Entity'].isin(ref_destination_location['Entity'])]['Entity']

print("Countries only in ref_origin_location:")
print(countries_only_in_origin_destination)
# Out:
# Countries only in ref_origin_location:
# 142     Andorra
# 143     Andorra
# 144     Andorra
# 145     Andorra
# 146     Andorra
#          ...
# 6563     Tuvalu
# 6564     Tuvalu
# 6565     Tuvalu
# 6566     Tuvalu
# 6567     Tuvalu
# Name: Entity, Length: 321, dtype: object

# %%
len(countries_only_in_origin_destination)
# Out:
# 321

# %%
len(countries_only_in_origin_destination.unique())
# Out:
# 17

# %%
print(countries_only_in_origin_destination.unique())
# Out:
# ['Andorra' 'Barbados' 'Brunei' 'Dominica' 'East Timor' 'Kiribati'
#  'Maldives' 'Marshall Islands' 'Myanmar' 'North Korea' 'Puerto Rico'
#  'Saint Vincent and the Grenadines' 'San Marino' 'Sao Tome and Principe'
#  'Seychelles' 'Tonga' 'Tuvalu']

# %%
# Years in ref_destination_location but not in ref_origin_location
years_only_in_ref_destination = ref_destination_location[~ref_destination_location['Year'].isin(ref_origin_location['Year'])]['Year']

print("Years only in ref_destination_location:", years_only_in_ref_destination)
# Out:
# Years only in ref_destination_location: Series([], Name: Year, dtype: int64)

# %% [markdown]
# What you see is that there are only 2 entities (terrorities/countries) in the destination df that are NOT in the origin df. In total, this makes up a difference of 11 rows more in the destination df. However, there are 17 countries in the origin df that are NOT in the destination df. In total, this makes up a difference of 321 more rows in the origin df.
#
# But in reality, the total difference (length data frames) is 7400-7095 = 305 data rows more in the destination df. This means that for some (or most) countries in the destination df, there are more years of data (more rows) per country/territory. In most of the cases. So in total, all years exist in all dfs, but per country the destination df has more data than the origin, so that has to be about more years of data.

# %% [markdown]
# --> There are more countries in origin than in destination df, BUT in destination is more data in terms of years than there is the origin df.

# %%
# Group by 'entity' and extract years
grouped_origin = ref_origin_location.groupby('Entity')['Year'].apply(set).reset_index()
grouped_origin
# Out:
#           Entity                                               Year
# 0    Afghanistan  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 1        Albania  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 2        Algeria  {1981, 1982, 1983, 1984, 1985, 1988, 1989, 199...
# 3        Andorra  {2022, 2002, 2003, 2005, 2006, 2007, 2008, 200...
# 4         Angola  {1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# ..           ...                                                ...
# 208      Vietnam  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 209        World  {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 210        Yemen  {1978, 1979, 1980, 1986, 1987, 1988, 1989, 199...
# 211       Zambia  {1968, 1969, 1970, 1971, 1972, 1973, 1974, 197...
# 212     Zimbabwe  {1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
#
# [213 rows x 2 columns]

# %%
grouped_destination = ref_destination_location.groupby('Entity')['Year'].apply(set).reset_index()
grouped_destination
# Out:
#                   Entity                                               Year
# 0            Afghanistan  {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 1                Albania  {1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...
# 2                Algeria  {1970, 1975, 1976, 1977, 1978, 1979, 1980, 198...
# 3                 Angola  {1976, 1977, 1978, 1979, 1980, 1981, 1982, 198...
# 4    Antigua and Barbuda                                       {2016, 2015}
# ..                   ...                                                ...
# 193              Vietnam  {1971, 1972, 1973, 1977, 1978, 1979, 1980, 198...
# 194                World  {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 195                Yemen  {1977, 1978, 1979, 1980, 1981, 1982, 1983, 198...
# 196               Zambia  {1965, 1966, 1967, 1968, 1969, 1970, 1971, 197...
# 197             Zimbabwe  {1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [198 rows x 2 columns]

# %%
# Merge the two DataFrames on 'entity' for comparison
merged_refugee = pd.merge(grouped_origin, grouped_destination, on='Entity', suffixes=('_origin', '_destination'), how='outer')
merged_refugee
# Out:
#           Entity                                        Year_origin  \
# 0    Afghanistan  {1979, 1980, 1981, 1982, 1983, 1984, 1985, 198...
# 1        Albania  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 2        Algeria  {1981, 1982, 1983, 1984, 1985, 1988, 1989, 199...
# 3        Andorra  {2022, 2002, 2003, 2005, 2006, 2007, 2008, 200...
# 4         Angola  {1960, 1961, 1962, 1963, 1964, 1965, 1966, 196...
# ..           ...                                                ...
# 210      Vietnam  {1964, 1965, 1966, 1967, 1968, 1969, 1970, 197...
# 211        World  {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 212        Yemen  {1978, 1979, 1980, 1986, 1987, 1988, 1989, 199...
# 213       Zambia  {1968, 1969, 1970, 1971, 1972, 1973, 1974, 197...
# 214     Zimbabwe  {1975, 1976, 1977, 1978, 1979, 1980, 1981, 198...
#
#                                       Year_destination
# 0    {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 1    {1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...
# 2    {1970, 1975, 1976, 1977, 1978, 1979, 1980, 198...
# 3                                                  NaN
# 4    {1976, 1977, 1978, 1979, 1980, 1981, 1982, 198...
# ..                                                 ...
# 210  {1971, 1972, 1973, 1977, 1978, 1979, 1980, 198...
# 211  {1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 212  {1977, 1978, 1979, 1980, 1981, 1982, 1983, 198...
# 213  {1965, 1966, 1967, 1968, 1969, 1970, 1971, 197...
# 214  {1980, 1981, 1982, 1983, 1984, 1985, 1986, 198...
#
# [215 rows x 3 columns]

# %%
# Calculate the difference in the number of years per entity
merged_refugee['difference'] = merged_refugee.apply(lambda row: len(row['Year_destination']) - len(row['Year_origin'])
                                                    if not (pd.isna(row['Year_origin']) or pd.isna(row['Year_destination'])) 
                                                    else np.nan, 
                                                    axis=1)
merged_refugee[['Entity', 'difference']]
# Out:
#           Entity  difference
# 0    Afghanistan       -15.0
# 1        Albania       -27.0
# 2        Algeria         9.0
# 3        Andorra         NaN
# 4         Angola       -16.0
# ..           ...         ...
# 210      Vietnam       -17.0
# 211        World         0.0
# 212        Yemen         6.0
# 213       Zambia        13.0
# 214     Zimbabwe        -4.0
#
# [215 rows x 2 columns]

# %%
merged_refugee.difference.sum()
# Out:
# 615.0

# %% [markdown]
# This makes sense, because in total, the destination df has 305 more rows than the origin df, but the origin destination has around 300 (321-11=310 exactly) more rows for countries, but then there are in total 615 more years data for the destination df. So in total around 300 (615-321+11 = 305 exactly) more rows.

# %%
# Show all rows for this specific print statement
with pd.option_context('display.max_rows', None):
    print(merged_refugee[['Entity', 'difference']])
# Out:
#                                 Entity  difference
# 0                          Afghanistan       -15.0
# 1                              Albania       -27.0
# 2                              Algeria         9.0
# 3                              Andorra         NaN
# 4                               Angola       -16.0
# 5                  Antigua and Barbuda       -20.0
# 6                            Argentina        11.0
# 7                              Armenia       -18.0
# 8                            Australia        30.0
# 9                              Austria        36.0
# 10                          Azerbaijan         0.0
# 11                             Bahamas         4.0
# 12                             Bahrain       -12.0
# 13                          Bangladesh        -1.0
# 14                            Barbados         NaN
# 15                             Belarus         0.0
# 16                             Belgium        35.0
# 17                              Belize        16.0
# 18                               Benin         4.0
# 19                              Bhutan       -31.0
# 20                             Bolivia         2.0
# 21              Bosnia and Herzegovina        -5.0
# 22                            Botswana        23.0
# 23                              Brazil        11.0
# 24                              Brunei         NaN
# 25                            Bulgaria       -20.0
# 26                        Burkina Faso         4.0
# 27                             Burundi         9.0
# 28                            Cambodia       -17.0
# 29                            Cameroon        16.0
# 30                              Canada        31.0
# 31                          Cape Verde       -25.0
# 32                      Cayman Islands         0.0
# 33            Central African Republic        18.0
# 34                                Chad       -17.0
# 35                               Chile         3.0
# 36                               China        -7.0
# 37                            Colombia        11.0
# 38                             Comoros       -26.0
# 39                               Congo         3.0
# 40                          Costa Rica        17.0
# 41                       Cote d'Ivoire        12.0
# 42                             Croatia         0.0
# 43                                Cuba        -3.0
# 44                             Curacao         1.0
# 45                              Cyprus        14.0
# 46                             Czechia       -17.0
# 47        Democratic Republic of Congo         4.0
# 48                             Denmark        32.0
# 49                            Djibouti        13.0
# 50                            Dominica         NaN
# 51                  Dominican Republic        11.0
# 52          East Asia and Pacific (WB)         0.0
# 53                          East Timor         NaN
# 54                             Ecuador        14.0
# 55                               Egypt        13.0
# 56                         El Salvador        -3.0
# 57                   Equatorial Guinea       -40.0
# 58                             Eritrea       -14.0
# 59                             Estonia       -11.0
# 60                            Eswatini        25.0
# 61                            Ethiopia        -1.0
# 62        Europe and Central Asia (WB)         0.0
# 63                 European Union (27)         0.0
# 64                                Fiji       -20.0
# 65                             Finland        20.0
# 66                              France        34.0
# 67                               Gabon        11.0
# 68                              Gambia         0.0
# 69                             Georgia        -2.0
# 70                             Germany        31.0
# 71                               Ghana         2.0
# 72                              Greece        10.0
# 73                             Grenada       -32.0
# 74                           Guatemala         1.0
# 75                              Guinea        -8.0
# 76                       Guinea-Bissau       -26.0
# 77                              Guyana       -14.0
# 78                               Haiti       -43.0
# 79               High-income countries         0.0
# 80                            Honduras        11.0
# 81                           Hong Kong        24.0
# 82                             Hungary       -22.0
# 83                             Iceland        14.0
# 84                               India        18.0
# 85                           Indonesia         0.0
# 86                                Iran         5.0
# 87                                Iraq        -5.0
# 88                             Ireland        20.0
# 89                              Israel       -10.0
# 90                               Italy        34.0
# 91                             Jamaica        -7.0
# 92                               Japan        21.0
# 93                              Jordan        24.0
# 94                          Kazakhstan         1.0
# 95                               Kenya        16.0
# 96                            Kiribati         NaN
# 97                              Kuwait         7.0
# 98                          Kyrgyzstan         1.0
# 99                                Laos       -36.0
# 100   Latin America and Caribbean (WB)         0.0
# 101                             Latvia        -7.0
# 102                            Lebanon        23.0
# 103                            Lesotho         6.0
# 104                            Liberia         6.0
# 105                              Libya       -13.0
# 106                      Liechtenstein        21.0
# 107                          Lithuania        -7.0
# 108               Low-income countries         0.0
# 109      Lower-middle-income countries         0.0
# 110                         Luxembourg        34.0
# 111                              Macao        12.0
# 112                         Madagascar       -12.0
# 113                             Malawi       -20.0
# 114                           Malaysia        14.0
# 115                           Maldives         NaN
# 116                               Mali         6.0
# 117                              Malta         8.0
# 118                   Marshall Islands         NaN
# 119                         Mauritania         1.0
# 120                          Mauritius       -20.0
# 121                             Mexico        22.0
# 122               Micronesia (country)         NaN
# 123  Middle East and North Africa (WB)         0.0
# 124            Middle-income countries         0.0
# 125                            Moldova        -6.0
# 126                             Monaco         3.0
# 127                           Mongolia       -14.0
# 128                         Montenegro         0.0
# 129                            Morocco        28.0
# 130                         Mozambique       -11.0
# 131                            Myanmar         NaN
# 132                            Namibia       -24.0
# 133                              Nauru         3.0
# 134                              Nepal        30.0
# 135                        Netherlands        34.0
# 136                        New Zealand        31.0
# 137                          Nicaragua        -1.0
# 138                              Niger         3.0
# 139                            Nigeria         9.0
# 140                 North America (WB)         1.0
# 141                        North Korea         NaN
# 142                    North Macedonia         1.0
# 143                             Norway        41.0
# 144                               Oman       -10.0
# 145                           Pakistan         9.0
# 146                              Palau         0.0
# 147                          Palestine        22.0
# 148                             Panama        13.0
# 149                   Papua New Guinea        17.0
# 150                           Paraguay        17.0
# 151                               Peru        17.0
# 152                        Philippines         2.0
# 153                             Poland       -19.0
# 154                           Portugal        18.0
# 155                        Puerto Rico         NaN
# 156                              Qatar         3.0
# 157                            Romania       -10.0
# 158                             Russia       -27.0
# 159                             Rwanda        -9.0
# 160              Saint Kitts and Nevis       -12.0
# 161                        Saint Lucia       -23.0
# 162   Saint Vincent and the Grenadines         NaN
# 163                              Samoa         0.0
# 164                         San Marino         NaN
# 165              Sao Tome and Principe         NaN
# 166                       Saudi Arabia        11.0
# 167                            Senegal        25.0
# 168                             Serbia         7.0
# 169                         Seychelles         NaN
# 170                       Sierra Leone         9.0
# 171                          Singapore        -9.0
# 172          Sint Maarten (Dutch part)         NaN
# 173                           Slovakia         1.0
# 174                           Slovenia         1.0
# 175                    Solomon Islands       -22.0
# 176                            Somalia        -3.0
# 177                       South Africa       -27.0
# 178                    South Asia (WB)         0.0
# 179                        South Korea         5.0
# 180                        South Sudan         1.0
# 181                              Spain        19.0
# 182                          Sri Lanka        -6.0
# 183            Sub-Saharan Africa (WB)         0.0
# 184                              Sudan        -4.0
# 185                           Suriname       -24.0
# 186                             Sweden        34.0
# 187                        Switzerland        35.0
# 188                              Syria        17.0
# 189                         Tajikistan         0.0
# 190                           Tanzania        16.0
# 191                           Thailand        15.0
# 192                               Togo        10.0
# 193                              Tonga         NaN
# 194                Trinidad and Tobago       -13.0
# 195                            Tunisia         2.0
# 196                             Turkey        18.0
# 197                       Turkmenistan         1.0
# 198           Turks and Caicos Islands        -2.0
# 199                             Tuvalu         NaN
# 200                             Uganda        12.0
# 201                            Ukraine        -2.0
# 202               United Arab Emirates        22.0
# 203                     United Kingdom        34.0
# 204                      United States        31.0
# 205      Upper-middle-income countries         0.0
# 206                            Uruguay         3.0
# 207                         Uzbekistan         1.0
# 208                            Vanuatu         2.0
# 209                          Venezuela        21.0
# 210                            Vietnam       -17.0
# 211                              World         0.0
# 212                              Yemen         6.0
# 213                             Zambia        13.0
# 214                           Zimbabwe        -4.0

# %% [markdown]
# All in all, there is too much difference to combine the numbers on how many refugees a country host in a particular year and how many refugees there are elsewhere that are born in that country. The data (mostly in years) does not allign. For certain years you could make an overview of this, but it is most logical to do for now to threat the two data sources/columns differently.

# %% [markdown]
# The above analysis may differ if we scope the data for the right years that are also availabe in climate data (which we will see and use later). Now all the data is used, starting from 1960, therefore there is a lot of missing data.. If you start from 2003, differences may be smaller. However, it is also not really necessary to combine the numbers in one dataframe for the plots and analysis that will follow.

# %% [markdown]
# So now first, loading other data in! And see the time frame we have in years.

# %% [markdown]
# # Loading in climate data

# %%
# Reading world risk index df
world_risk_index= pd.read_csv('worldriskindex-trend.csv')
world_risk_index
# Out:
#       WRI.Country ISO3.Code  Year      W      E      V      S      C      A  \
# 0     Afghanistan       AFG  2000   4.25   0.25  72.41  64.20  78.17  75.65
# 1         Albania       ALB  2000   6.55   2.38  18.00  12.72  44.07  10.40
# 2         Algeria       DZA  2000   9.80   2.65  36.21  22.80  51.88  40.15
# 3         Andorra       AND  2000   0.32   0.02   5.11   2.34   2.18  26.18
# 4          Angola       AGO  2000  10.99   2.18  55.44  35.59  62.75  76.28
# ...           ...       ...   ...    ...    ...    ...    ...    ...    ...
# 4627      Vanuatu       VUT  2023  10.90   5.80  20.49  13.77  12.06  51.81
# 4628     Viet Nam       VNM  2023  24.39  26.73  22.25  21.55  12.50  40.90
# 4629        Yemen       YEM  2023  24.39   9.12  65.24  60.26  69.29  66.50
# 4630       Zambia       ZMB  2023   2.94   0.28  30.78  34.17  13.91  61.36
# 4631     Zimbabwe       ZWE  2023   2.52   0.20  31.73  31.54  14.88  68.08
#
#        S_01  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  AI_04b_Base  \
# 0     71.25  ...       100.00           24        91.54           24
# 1     51.82  ...        19.61           97        19.81           97
# 2     47.80  ...        40.23           86        42.01           86
# 3     27.62  ...        12.85           98        27.52           95
# 4     61.34  ...        84.23           31       100.00           21
# ...     ...  ...          ...          ...          ...          ...
# 4627  60.99  ...        68.00           62        66.77           62
# 4628  49.52  ...        48.08           83        48.37           81
# 4629  67.34  ...        59.76           72        63.47           66
# 4630  61.77  ...        37.12           91        42.03           87
# 4631  62.08  ...        43.86           86        43.35           86
#
#       AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  \
# 0          100.00            5        81.55        85.47        70.41
# 1           27.05           91        49.54      1232.02         0.01
# 2           43.09           78        44.33      1759.71        15.96
# 3           36.20           84        30.46      6112.59        60.03
# 4           74.69           21        56.16       751.90        93.27
# ...           ...          ...          ...          ...          ...
# 4627        47.40           75        60.30      1318.79        31.68
# 4628        36.05           85        47.90      3698.73        24.27
# 4629        60.51           52        65.42       841.23        77.87
# 4630        42.72           81        63.80      1028.14        59.22
# 4631        48.28           74        82.72       288.13        93.27
#
#       AI_05b_Base
# 0           14.53
# 1            0.00
# 2            0.30
# 3            7.22
# 4          325.00
# ...           ...
# 4627         4.60
# 4628         3.20
# 4629        29.10
# 4630        11.00
# 4631       193.40
#
# [4632 rows x 248 columns]

# %% [markdown]
# The world risk index data is available from 2000 till 2023. The refugee data is available from 1960 till 2022. The choice in this study is to investigate 20 years, from 2003 up to and including 2022.

# %%
world_risk_index = world_risk_index[world_risk_index['Year']<=2022]
world_risk_index
# Out:
#       WRI.Country ISO3.Code  Year      W      E      V      S      C      A  \
# 0     Afghanistan       AFG  2000   4.25   0.25  72.41  64.20  78.17  75.65
# 1         Albania       ALB  2000   6.55   2.38  18.00  12.72  44.07  10.40
# 2         Algeria       DZA  2000   9.80   2.65  36.21  22.80  51.88  40.15
# 3         Andorra       AND  2000   0.32   0.02   5.11   2.34   2.18  26.18
# 4          Angola       AGO  2000  10.99   2.18  55.44  35.59  62.75  76.28
# ...           ...       ...   ...    ...    ...    ...    ...    ...    ...
# 4434      Vanuatu       VUT  2022  10.90   5.80  20.49  13.77  12.06  51.81
# 4435     Viet Nam       VNM  2022  24.39  26.73  22.25  21.55  12.50  40.90
# 4436        Yemen       YEM  2022  24.39   9.12  65.24  60.26  69.29  66.50
# 4437       Zambia       ZMB  2022   2.94   0.28  30.78  34.17  13.91  61.36
# 4438     Zimbabwe       ZWE  2022   2.52   0.20  31.73  31.54  14.88  68.08
#
#        S_01  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  AI_04b_Base  \
# 0     71.25  ...       100.00           24        91.54           24
# 1     51.82  ...        19.61           97        19.81           97
# 2     47.80  ...        40.23           86        42.01           86
# 3     27.62  ...        12.85           98        27.52           95
# 4     61.34  ...        84.23           31       100.00           21
# ...     ...  ...          ...          ...          ...          ...
# 4434  60.99  ...        68.00           62        66.77           62
# 4435  49.52  ...        48.08           83        48.37           81
# 4436  67.34  ...        59.76           72        63.47           66
# 4437  61.77  ...        37.12           91        42.03           87
# 4438  62.08  ...        43.86           86        43.35           86
#
#       AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  \
# 0          100.00            5        81.55        85.47        70.41
# 1           27.05           91        49.54      1232.02         0.01
# 2           43.09           78        44.33      1759.71        15.96
# 3           36.20           84        30.46      6112.59        60.03
# 4           74.69           21        56.16       751.90        93.27
# ...           ...          ...          ...          ...          ...
# 4434        47.40           75        60.30      1318.79        31.68
# 4435        36.05           85        47.90      3698.73        24.27
# 4436        60.51           52        65.42       841.23        77.87
# 4437        42.72           81        63.80      1028.14        59.22
# 4438        48.28           74        82.72       288.13        93.27
#
#       AI_05b_Base
# 0           14.53
# 1            0.00
# 2            0.30
# 3            7.22
# 4          325.00
# ...           ...
# 4434         4.60
# 4435         3.20
# 4436        29.10
# 4437        11.00
# 4438       193.40
#
# [4439 rows x 248 columns]

# %%
world_risk_index = world_risk_index[world_risk_index['Year']>=2003]
world_risk_index
# Out:
#       WRI.Country ISO3.Code  Year      W      E      V      S      C      A  \
# 579   Afghanistan       AFG  2003   4.22   0.25  71.17  62.53  74.70  77.17
# 580       Albania       ALB  2003   7.95   2.38  26.55   9.53  47.08  41.69
# 581       Algeria       DZA  2003  10.04   2.64  38.15  22.54  52.96  46.51
# 582       Andorra       AND  2003   0.26   0.02   3.40   1.68   2.02  11.56
# 583        Angola       AGO  2003  11.01   2.22  54.64  36.10  60.73  74.42
# ...           ...       ...   ...    ...    ...    ...    ...    ...    ...
# 4434      Vanuatu       VUT  2022  10.90   5.80  20.49  13.77  12.06  51.81
# 4435     Viet Nam       VNM  2022  24.39  26.73  22.25  21.55  12.50  40.90
# 4436        Yemen       YEM  2022  24.39   9.12  65.24  60.26  69.29  66.50
# 4437       Zambia       ZMB  2022   2.94   0.28  30.78  34.17  13.91  61.36
# 4438     Zimbabwe       ZWE  2022   2.52   0.20  31.73  31.54  14.88  68.08
#
#        S_01  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  AI_04b_Base  \
# 579   67.49  ...        77.27           41        83.88           41
# 580   51.80  ...        19.31           97        19.06           97
# 581   48.03  ...        41.51           87        41.52           87
# 582    4.69  ...         0.01           99         0.01           99
# 583   60.66  ...        72.90           46       100.00           21
# ...     ...  ...          ...          ...          ...          ...
# 4434  60.99  ...        68.00           62        66.77           62
# 4435  49.52  ...        48.08           83        48.37           81
# 4436  67.34  ...        59.76           72        63.47           66
# 4437  61.77  ...        37.12           91        42.03           87
# 4438  62.08  ...        43.86           86        43.35           86
#
#       AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  \
# 579         92.14            6        69.97       252.88        86.91
# 580         27.40           93        45.54      1794.80        41.28
# 581         21.29           96        41.83      2429.99        51.00
# 582         36.65           86        25.51      7375.33        56.36
# 583         73.69           26        53.27      1134.39        92.98
# ...           ...          ...          ...          ...          ...
# 4434        47.40           75        60.30      1318.79        31.68
# 4435        36.05           85        47.90      3698.73        24.27
# 4436        60.51           52        65.42       841.23        77.87
# 4437        42.72           81        63.80      1028.14        59.22
# 4438        48.28           74        82.72       288.13        93.27
#
#       AI_05b_Base
# 579          35.7
# 580           2.4
# 581           4.3
# 582           6.1
# 583          98.2
# ...           ...
# 4434          4.6
# 4435          3.2
# 4436         29.1
# 4437         11.0
# 4438        193.4
#
# [3860 rows x 248 columns]

# %% [markdown]
# # Merging climate data with refugee data

# %% [markdown]
# We start with merging the world risk index data with the origin location refugee data

# %%
ref_origin_location = ref_origin_location[ref_origin_location['Year'] >= 2003]
ref_origin_location
# Out:
#            Entity Code  Year  \
# 24    Afghanistan  AFG  2003
# 25    Afghanistan  AFG  2004
# 26    Afghanistan  AFG  2005
# 27    Afghanistan  AFG  2006
# 28    Afghanistan  AFG  2007
# ...           ...  ...   ...
# 7090     Zimbabwe  ZWE  2018
# 7091     Zimbabwe  ZWE  2019
# 7092     Zimbabwe  ZWE  2020
# 7093     Zimbabwe  ZWE  2021
# 7094     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of origin
# 24                                              2136039
# 25                                              2414460
# 26                                              2166139
# 27                                              2107510
# 28                                              3057655
# ...                                                 ...
# 7090                                              15618
# 7091                                              10045
# 7092                                               8575
# 7093                                               8115
# 7094                                               7008
#
# [3931 rows x 4 columns]

# %% [markdown]
# Now we have the complete data frames (total) for the analysis, we check the missing values.

# %%
ref_origin_location[ref_origin_location.isna().any(axis=1)]
# Out:
#                              Entity Code  Year  \
# 1825     East Asia and Pacific (WB)  NaN  2003
# 1826     East Asia and Pacific (WB)  NaN  2004
# 1827     East Asia and Pacific (WB)  NaN  2005
# 1828     East Asia and Pacific (WB)  NaN  2006
# 1829     East Asia and Pacific (WB)  NaN  2007
# ...                             ...  ...   ...
# 6763  Upper-middle-income countries  NaN  2018
# 6764  Upper-middle-income countries  NaN  2019
# 6765  Upper-middle-income countries  NaN  2020
# 6766  Upper-middle-income countries  NaN  2021
# 6767  Upper-middle-income countries  NaN  2022
#
#       Refugee population by country or territory of origin
# 1825                                             708146
# 1826                                             711437
# 1827                                             728168
# 1828                                             806559
# 1829                                             726465
# ...                                                 ...
# 6763                                            1169550
# 6764                                            1214177
# 6765                                            1276535
# 6766                                            1207833
# 6767                                            1168062
#
# [260 rows x 4 columns]

# %%
ref_origin_location.isna().sum()
# Out:
# Entity                                                    0
# Code                                                    260
# Year                                                      0
# Refugee population by country or territory of origin      0
# dtype: int64

# %%
ref_origin_location[ref_origin_location[['Entity', 'Year', 'Refugee population by country or territory of origin']].isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Refugee population by country or territory of origin]
# Index: []

# %% [markdown]
# Only missing values in country code, which is no problem, because this are for example continents.

# %% [markdown]
# Eventually, we want to merge the refugee and world risk index data, so we check how many countries are only in one dataframe or the other.

# %%
# Countries in ref_origin_location but not in world_risk_index df
countries_in_org_not_risk = ref_origin_location[~ref_origin_location['Entity'].isin(world_risk_index['WRI.Country'])]['Entity']

print("Countries only in ref_destination_location, NOT in world risk index df:")
print(set(countries_in_org_not_risk))
print(len(set(countries_in_org_not_risk)))
# Out:
# Countries only in ref_destination_location, NOT in world risk index df:
# {'North America (WB)', 'Latin America and Caribbean (WB)', 'South Asia (WB)', 'Curacao', 'Cayman Islands', 'United States', 'North Korea', 'Congo', 'Europe and Central Asia (WB)', 'Libya', 'Low-income countries', 'Hong Kong', 'East Asia and Pacific (WB)', 'Vietnam', 'Russia', 'Bolivia', 'Moldova', 'High-income countries', 'World', 'Lower-middle-income countries', 'United Kingdom', 'Turks and Caicos Islands', 'South Korea', 'Czechia', 'Middle-income countries', 'Syria', 'Macao', 'East Timor', 'Sub-Saharan Africa (WB)', 'Middle East and North Africa (WB)', 'Palestine', 'Tanzania', 'Iran', 'Laos', 'Brunei', 'European Union (27)', 'Venezuela', 'Upper-middle-income countries'}
# 38

# %% [markdown]
# A lot of the 38 names above are not countries, but continents, which we will not include anyway. So it is no poblem that these do not occur in both dfs.

# %% [markdown]
# And sometimes, the country code is in both df's, but the country name is different. For example, for Russia this is the case. Code: RUS.

# %%
# Countries in ref_origin_location but not in world_risk_index df #based on country code
countries_in_org_not_risk_based_on_code = ref_origin_location[~ref_origin_location['Code'].isin(world_risk_index['ISO3.Code'])]['Code']

print("Countries only in ref_destination_location, NOT in world risk index df:")
print(set(countries_in_org_not_risk_based_on_code))
print(len(set(countries_in_org_not_risk_based_on_code)))
# Out:
# Countries only in ref_destination_location, NOT in world risk index df:
# {'CYM', 'MAC', 'HKG', 'TCA', nan, 'CUW', 'PSE', 'OWID_WRL'}
# 8

# %% [markdown]
# We check also the other way around: countries that are only in the world risk index and not the ref origin location df.

# %%
# Countries in world_risk_index df but not in ref_origin_location
countries_in_worldrisk_not_origin = world_risk_index[~world_risk_index['WRI.Country'].isin(ref_origin_location['Entity'])]['WRI.Country']

print("Countries only in world risk index, NOT in ref_origin_location:")
print(set(countries_in_worldrisk_not_origin))
print(len(set(countries_in_worldrisk_not_origin)))
# Out:
# Countries only in world risk index, NOT in ref_origin_location:
# {'Bolivarian Republic of Venezuela', 'United States of America', 'United Kingdom of Great Britain and Northern Ireland', 'Iran (Islamic Republic of)', 'San Marino', 'Plurinational State of Bolivia', 'Republic of Congo', 'Brunei Darussalam', 'Republic of Moldova', 'United Republic of Tanzania', 'Czech Republic', 'Libyan Arab Jamahiriya', 'Syrian Arab Republic', 'Viet Nam', "Lao People's Democratic Republic", 'Federated States of Micronesia', 'Russian Federation', "Democratic People's Republic of Korea", 'Timor-Leste', 'Republic of Korea'}
# 20

# %%
# Countries in world_risk_index df but not in ref_origin_location_2000 #based on country code
countries_in_worldrisk_not_origin_based_on_code = world_risk_index[~world_risk_index['ISO3.Code'].isin(ref_origin_location['Code'])]['ISO3.Code']

print("Countries only in world risk index, NOT in ref_origin_location df:")
print(set(countries_in_worldrisk_not_origin_based_on_code))
print(len(set(countries_in_worldrisk_not_origin_based_on_code)))
# Out:
# Countries only in world risk index, NOT in ref_origin_location df:
# {'SMR', 'FSM'}
# 2

# %% [markdown]
# In the end, only few, small countries (islands or palestina for example) are not in both countries. The only well known countries that do not overlap between the datasets are Palestine and Hong Kong. Further, there are only some minor countries, small islands in Oceania that are not listed in both datasets.

# %% [markdown]
# We go on with checking for missing values.

# %%
world_risk_index.isna().sum()
# Out:
# WRI.Country    0
# ISO3.Code      0
# Year           0
# W              0
# E              0
#               ..
# AI_04c_Base    0
# AI_05a_Norm    0
# AI_05a_Base    0
# AI_05b_Norm    0
# AI_05b_Base    0
# Length: 248, dtype: int64

# %%
# Show all rows for this specific print statement
with pd.option_context('display.max_rows', None):
    print(world_risk_index.isna().sum())
# Out:
# WRI.Country       0
# ISO3.Code         0
# Year              0
# W                 0
# E                 0
# V                 0
# S                 0
# C                 0
# A                 0
# S_01              0
# S_02              0
# S_03              0
# S_04              0
# S_05              0
# C_01              0
# C_02              0
# C_03              0
# A_01              0
# A_02              0
# A_03              0
# EI_01             0
# EI_02             0
# EI_03             0
# EI_04             0
# EI_05             0
# EI_06             0
# EI_07             0
# SI_01             0
# SI_02             0
# SI_03             0
# SI_04             0
# SI_05             0
# SI_06             0
# SI_07             0
# SI_08             0
# SI_09             0
# SI_10             0
# SI_11             0
# SI_12             0
# SI_13             0
# SI_14             0
# CI_01             0
# CI_02             0
# CI_03             0
# CI_04             0
# CI_05             0
# CI_06             0
# CI_07             0
# AI_01             0
# AI_02             0
# AI_03             0
# AI_04             0
# EI_01a_Norm       0
# EI_01a_Base       0
# EI_01b_Norm       0
# EI_01b_Base       0
# EI_01c_Norm       0
# EI_01c_Base       0
# EI_01d_Norm       0
# EI_01d_Base       0
# EI_01e_Norm       0
# EI_01e_Base       0
# EI_01f_Norm       0
# EI_01f_Base       0
# EI_02a_Norm       0
# EI_02a_Base       0
# EI_02b_Norm       0
# EI_02b_Base       0
# EI_02c_Norm       0
# EI_02c_Base       0
# EI_02d_Norm       0
# EI_02d_Base       0
# EI_02e_Norm       0
# EI_02e_Base       0
# EI_02f_Norm       0
# EI_02f_Base       0
# EI_03a_Norm       0
# EI_03a_Base       0
# EI_03b_Norm       0
# EI_03b_Base       0
# EI_03c_Norm       0
# EI_03c_Base       0
# EI_03d_Norm       0
# EI_03d_Base       0
# EI_03e_Norm       0
# EI_03e_Base       0
# EI_03f_Norm       0
# EI_03f_Base       0
# EI_04a_Norm       0
# EI_04a_Base       0
# EI_04b_Norm       0
# EI_04b_Base       0
# EI_04c_Norm       0
# EI_04c_Base       0
# EI_04d_Norm       0
# EI_04d_Base       0
# EI_04e_Norm       0
# EI_04e_Base       0
# EI_04f_Norm       0
# EI_04f_Base       0
# EI_05a_Norm       0
# EI_05a_Base       0
# EI_05b_Norm       0
# EI_05b_Base       0
# EI_05c_Norm       0
# EI_05c_Base       0
# EI_05d_Norm       0
# EI_05d_Base       0
# EI_05e_Norm       0
# EI_05e_Base       0
# EI_05f_Norm       0
# EI_05f_Base       0
# EI_06a_Norm       0
# EI_06a_Base       0
# EI_06b_Norm       0
# EI_06b_Base       0
# EI_06c_Norm       0
# EI_06c_Base       0
# EI_06d_Norm       0
# EI_06d_Base       0
# EI_06e_Norm       0
# EI_06e_Base       0
# EI_06f_Norm       0
# EI_06f_Base       0
# EI_07a_Norm       0
# EI_07a_Base       0
# EI_07b_Norm       0
# EI_07b_Base       0
# SI_01a_Norm       0
# SI_01a_Base       0
# SI_01b_Norm       0
# SI_01b_Base       0
# SI_02a_Norm       0
# SI_02a_Base       0
# SI_02b_Norm       0
# SI_02b_Base       0
# SI_03a_Norm       0
# SI_03a_Base       0
# SI_03b_Norm       0
# SI_03b_Base       0
# SI_04a_Norm       0
# SI_04a_Base       0
# SI_04b_Norm       0
# SI_04b_Base       0
# SI_05a_Norm       0
# SI_05a_Base       0
# SI_05b_Norm       0
# SI_05b_Base       0
# SI_06a_Norm       0
# SI_06a_Base       0
# SI_06b_Norm       0
# SI_06b_Base       0
# SI_07a_Norm       0
# SI_07a_Base       0
# SI_07b_Norm       0
# SI_07b_Base       0
# SI_08a_Norm       0
# SI_08a_Base       0
# SI_08b_Norm       0
# SI_08b_Base       0
# SI_09a_Norm       0
# SI_09a_Base       0
# SI_09b_Norm       0
# SI_09b_Base       0
# SI_10_Norm        0
# SI_10_Base        0
# SI_10a_Norm       0
# SI_10a_Base       0
# SI_10b_Norm       0
# SI_10b_Base       0
# SI_11_Norm        0
# SI_11_Base        0
# SI_12a_Norm       0
# SI_12a_Base       0
# SI_12b_Norm       0
# SI_12b_Base       0
# SI_13a_Norm       0
# SI_13a_Base       0
# SI_13b_Norm       0
# SI_13b_Base       0
# SI_14a_Norm    1158
# SI_14a_Base       0
# SI_14b_Norm       0
# SI_14b_Base       0
# SI_15a_Norm       0
# SI_15a_Base       0
# SI_15b_Norm       0
# SI_15b_Base       0
# SI_15c_Norm       0
# SI_15c_Base       0
# SI_15d_Norm       0
# SI_15d_Base       0
# CI_01a_Norm       0
# CI_01a_Base       0
# CI_01b_Norm       0
# CI_01b_Base       0
# CI_02a_Norm       0
# CI_02a_Base       0
# CI_02b_Norm       0
# CI_02b_Base       0
# CI_03a_Norm       0
# CI_03a_Base       0
# CI_03b_Norm       0
# CI_03b_Base       0
# CI_04a_Norm       0
# CI_04a_Base       0
# CI_04b_Norm       0
# CI_04b_Base       0
# CI_05a_Norm       0
# CI_05a_Base       0
# CI_05b_Norm       0
# CI_05b_Base       0
# CI_06a_Norm       0
# CI_06a_Base       0
# CI_06b_Norm       0
# CI_06b_Base       0
# CI_07a_Norm       0
# CI_07a_Base       0
# CI_07b_Norm       0
# CI_07b_Base       0
# AI_01a_Norm       0
# AI_01a_Base       0
# AI_01b_Norm       0
# AI_01b_Base       0
# AI_01c_Norm       0
# AI_01c_Base       0
# AI_02a_Norm       0
# AI_02a_Base       0
# AI_02b_Norm       0
# AI_02b_Base       0
# AI_02c_Norm       0
# AI_02c_Base       0
# AI_03a_Norm       0
# AI_03a_Base       0
# AI_03b_Norm       0
# AI_03b_Base       0
# AI_03c_Norm       0
# AI_03c_Base       0
# AI_04a_Norm       0
# AI_04a_Base       0
# AI_04b_Norm       0
# AI_04b_Base       0
# AI_04c_Norm       0
# AI_04c_Base       0
# AI_05a_Norm       0
# AI_05a_Base       0
# AI_05b_Norm       0
# AI_05b_Base       0
# dtype: int64

# %% [markdown]
# We drop the one column with missing values: SI_14a_Norm. The variable is: Internally Displaced Persons Due To Violence And Conflict. We actually do not need the IDP data, because we do cross country analysis. Also, IDPs are already segmented in categories 'climate' and 'conflict', which is not suitable for this research.

# %%
world_risk_index = world_risk_index.drop(columns=['SI_14a_Norm'])

# %%
world_risk_index.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Now we rename columns to prepare the merge.

# %%
# Change the name of one column
ref_origin_location = ref_origin_location.rename(columns={'Entity':'Country'})
ref_origin_location
# Out:
#           Country Code  Year  \
# 24    Afghanistan  AFG  2003
# 25    Afghanistan  AFG  2004
# 26    Afghanistan  AFG  2005
# 27    Afghanistan  AFG  2006
# 28    Afghanistan  AFG  2007
# ...           ...  ...   ...
# 7090     Zimbabwe  ZWE  2018
# 7091     Zimbabwe  ZWE  2019
# 7092     Zimbabwe  ZWE  2020
# 7093     Zimbabwe  ZWE  2021
# 7094     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of origin
# 24                                              2136039
# 25                                              2414460
# 26                                              2166139
# 27                                              2107510
# 28                                              3057655
# ...                                                 ...
# 7090                                              15618
# 7091                                              10045
# 7092                                               8575
# 7093                                               8115
# 7094                                               7008
#
# [3931 rows x 4 columns]

# %%
# Change the name of columns
world_risk_index= world_risk_index.rename(columns={'WRI.Country':'Country'})
world_risk_index= world_risk_index.rename(columns={'ISO3.Code':'Code'})
world_risk_index
# Out:
#           Country Code  Year      W      E      V      S      C      A   S_01  \
# 579   Afghanistan  AFG  2003   4.22   0.25  71.17  62.53  74.70  77.17  67.49
# 580       Albania  ALB  2003   7.95   2.38  26.55   9.53  47.08  41.69  51.80
# 581       Algeria  DZA  2003  10.04   2.64  38.15  22.54  52.96  46.51  48.03
# 582       Andorra  AND  2003   0.26   0.02   3.40   1.68   2.02  11.56   4.69
# 583        Angola  AGO  2003  11.01   2.22  54.64  36.10  60.73  74.42  60.66
# ...           ...  ...   ...    ...    ...    ...    ...    ...    ...    ...
# 4434      Vanuatu  VUT  2022  10.90   5.80  20.49  13.77  12.06  51.81  60.99
# 4435     Viet Nam  VNM  2022  24.39  26.73  22.25  21.55  12.50  40.90  49.52
# 4436        Yemen  YEM  2022  24.39   9.12  65.24  60.26  69.29  66.50  67.34
# 4437       Zambia  ZMB  2022   2.94   0.28  30.78  34.17  13.91  61.36  61.77
# 4438     Zimbabwe  ZWE  2022   2.52   0.20  31.73  31.54  14.88  68.08  62.08
#
#       ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  AI_04b_Base  AI_04c_Norm  \
# 579   ...        77.27           41        83.88           41        92.14
# 580   ...        19.31           97        19.06           97        27.40
# 581   ...        41.51           87        41.52           87        21.29
# 582   ...         0.01           99         0.01           99        36.65
# 583   ...        72.90           46       100.00           21        73.69
# ...   ...          ...          ...          ...          ...          ...
# 4434  ...        68.00           62        66.77           62        47.40
# 4435  ...        48.08           83        48.37           81        36.05
# 4436  ...        59.76           72        63.47           66        60.51
# 4437  ...        37.12           91        42.03           87        42.72
# 4438  ...        43.86           86        43.35           86        48.28
#
#       AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  AI_05b_Base
# 579             6        69.97       252.88        86.91         35.7
# 580            93        45.54      1794.80        41.28          2.4
# 581            96        41.83      2429.99        51.00          4.3
# 582            86        25.51      7375.33        56.36          6.1
# 583            26        53.27      1134.39        92.98         98.2
# ...           ...          ...          ...          ...          ...
# 4434           75        60.30      1318.79        31.68          4.6
# 4435           85        47.90      3698.73        24.27          3.2
# 4436           52        65.42       841.23        77.87         29.1
# 4437           81        63.80      1028.14        59.22         11.0
# 4438           74        82.72       288.13        93.27        193.4
#
# [3860 rows x 247 columns]

# %% [markdown]
# We merge on either country name or country code, because both or one of the two can overlap.

# %%
# Merge DataFrames on 'Year' and 'Code'
refugeeorigin_worldrisk = pd.merge(ref_origin_location, world_risk_index, on=['Year', 'Code'], how='inner')
refugeeorigin_worldrisk
# Out:
#         Country_x Code  Year  \
# 0     Afghanistan  AFG  2003
# 1     Afghanistan  AFG  2004
# 2     Afghanistan  AFG  2005
# 3     Afghanistan  AFG  2006
# 4     Afghanistan  AFG  2007
# ...           ...  ...   ...
# 3562     Zimbabwe  ZWE  2018
# 3563     Zimbabwe  ZWE  2019
# 3564     Zimbabwe  ZWE  2020
# 3565     Zimbabwe  ZWE  2021
# 3566     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of origin    Country_y     W  \
# 0                                               2136039     Afghanistan  4.22
# 1                                               2414460     Afghanistan  4.20
# 2                                               2166139     Afghanistan  4.12
# 3                                               2107510     Afghanistan  4.14
# 4                                               3057655     Afghanistan  4.17
# ...                                                 ...             ...   ...
# 3562                                              15618        Zimbabwe  2.50
# 3563                                              10045        Zimbabwe  2.55
# 3564                                               8575        Zimbabwe  2.54
# 3565                                               8115        Zimbabwe  2.53
# 3566                                               7008        Zimbabwe  2.52
#
#          E      V      S      C  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  \
# 0     0.25  71.17  62.53  74.70  ...        77.27           41        83.88
# 1     0.25  70.48  63.15  73.40  ...        72.62           50        71.58
# 2     0.25  67.94  62.22  69.49  ...        71.87           58        71.73
# 3     0.25  68.48  61.59  75.41  ...        71.07           58        71.09
# 4     0.25  69.62  61.97  76.98  ...        70.00           63        69.70
# ...    ...    ...    ...    ...  ...          ...          ...          ...
# 3562  0.20  31.27  30.67  15.24  ...        44.93           89        43.43
# 3563  0.20  32.58  32.41  15.45  ...        43.26           90        41.92
# 3564  0.20  32.23  31.81  15.39  ...        44.29           86        43.58
# 3565  0.20  32.04  31.69  15.34  ...        43.86           86        43.35
# 3566  0.20  31.73  31.54  14.88  ...        43.86           86        43.35
#
#       AI_04b_Base  AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  \
# 0              41        92.14            6        69.97       252.88
# 1              50       100.00            2        73.91       184.09
# 2              58       100.00            9        73.35       203.37
# 3              58        86.07           18        77.87       179.24
# 4              63       100.00            4        77.87       200.60
# ...           ...          ...          ...          ...          ...
# 3562           89        45.21           78        81.55       271.45
# 3563           90        51.49           75        82.72       245.70
# 3564           86        49.38           74        84.04       210.90
# 3565           86        48.28           74        82.72       288.13
# 3566           86        48.28           74        82.72       288.13
#
#       AI_05b_Norm  AI_05b_Base
# 0           86.91         35.7
# 1           77.87         16.4
# 2           67.55         10.6
# 3           56.41          6.8
# 4           62.88          8.7
# ...           ...          ...
# 3562        70.58         10.6
# 3563        93.27        255.3
# 3564        92.64        557.2
# 3565        89.84         98.5
# 3566        93.27        193.4
#
# [3567 rows x 249 columns]

# %%
refugeeorigin_worldrisk = refugeeorigin_worldrisk.drop(columns=['Country_y'])
refugeeorigin_worldrisk = refugeeorigin_worldrisk.rename(columns={'Country_x':'Country'})
refugeeorigin_worldrisk
# Out:
#           Country Code  Year  \
# 0     Afghanistan  AFG  2003
# 1     Afghanistan  AFG  2004
# 2     Afghanistan  AFG  2005
# 3     Afghanistan  AFG  2006
# 4     Afghanistan  AFG  2007
# ...           ...  ...   ...
# 3562     Zimbabwe  ZWE  2018
# 3563     Zimbabwe  ZWE  2019
# 3564     Zimbabwe  ZWE  2020
# 3565     Zimbabwe  ZWE  2021
# 3566     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of origin     W     E      V  \
# 0                                               2136039     4.22  0.25  71.17
# 1                                               2414460     4.20  0.25  70.48
# 2                                               2166139     4.12  0.25  67.94
# 3                                               2107510     4.14  0.25  68.48
# 4                                               3057655     4.17  0.25  69.62
# ...                                                 ...      ...   ...    ...
# 3562                                              15618     2.50  0.20  31.27
# 3563                                              10045     2.55  0.20  32.58
# 3564                                               8575     2.54  0.20  32.23
# 3565                                               8115     2.53  0.20  32.04
# 3566                                               7008     2.52  0.20  31.73
#
#           S      C      A  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  \
# 0     62.53  74.70  77.17  ...        77.27           41        83.88
# 1     63.15  73.40  75.53  ...        72.62           50        71.58
# 2     62.22  69.49  72.54  ...        71.87           58        71.73
# 3     61.59  75.41  69.13  ...        71.07           58        71.09
# 4     61.97  76.98  70.73  ...        70.00           63        69.70
# ...     ...    ...    ...  ...          ...          ...          ...
# 3562  30.67  15.24  65.41  ...        44.93           89        43.43
# 3563  32.41  15.45  69.09  ...        43.26           90        41.92
# 3564  31.81  15.39  68.36  ...        44.29           86        43.58
# 3565  31.69  15.34  67.64  ...        43.86           86        43.35
# 3566  31.54  14.88  68.08  ...        43.86           86        43.35
#
#       AI_04b_Base  AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  \
# 0              41        92.14            6        69.97       252.88
# 1              50       100.00            2        73.91       184.09
# 2              58       100.00            9        73.35       203.37
# 3              58        86.07           18        77.87       179.24
# 4              63       100.00            4        77.87       200.60
# ...           ...          ...          ...          ...          ...
# 3562           89        45.21           78        81.55       271.45
# 3563           90        51.49           75        82.72       245.70
# 3564           86        49.38           74        84.04       210.90
# 3565           86        48.28           74        82.72       288.13
# 3566           86        48.28           74        82.72       288.13
#
#       AI_05b_Norm  AI_05b_Base
# 0           86.91         35.7
# 1           77.87         16.4
# 2           67.55         10.6
# 3           56.41          6.8
# 4           62.88          8.7
# ...           ...          ...
# 3562        70.58         10.6
# 3563        93.27        255.3
# 3564        92.64        557.2
# 3565        89.84         98.5
# 3566        93.27        193.4
#
# [3567 rows x 248 columns]

# %%
refugeeorigin_worldrisk= refugeeorigin_worldrisk.rename(columns={'Refugee population by country or territory of origin':'#refugees_origin'})

# %%
refugeeorigin_worldrisk.to_csv('refugeeorigin_worldrisk.csv',index=False)

# %% [markdown]
# Now we start preparing the merge for the world risk index with the refugee destination data.
#
# (All the tests we did previously for differences between world risk index and ref_origin_location in countries will NOT be conducted again for differences between world_risk_index and ref_destionation_location, because we know already that, in terms of listed countries, the difference between origin and destination is acceptable and therefore also between destination and world risk index.)

# %%
ref_destination_location = ref_destination_location[ref_destination_location['Year']>=2000]
ref_destination_location
# Out:
#            Entity Code  Year  \
# 8     Afghanistan  AFG  2001
# 9     Afghanistan  AFG  2003
# 10    Afghanistan  AFG  2004
# 11    Afghanistan  AFG  2005
# 12    Afghanistan  AFG  2006
# ...           ...  ...   ...
# 7395     Zimbabwe  ZWE  2018
# 7396     Zimbabwe  ZWE  2019
# 7397     Zimbabwe  ZWE  2020
# 7398     Zimbabwe  ZWE  2021
# 7399     Zimbabwe  ZWE  2022
#
#       Refugee population by country or territory of asylum
# 8                                                    10
# 9                                                    24
# 10                                                   31
# 11                                                   31
# 12                                                   34
# ...                                                 ...
# 7395                                               7795
# 7396                                               8956
# 7397                                               9261
# 7398                                               9483
# 7399                                              10475
#
# [3944 rows x 4 columns]

# %%
ref_destination_location = ref_destination_location.rename(columns={'Refugee population by country or territory of asylum':'#refugees_destination'})
ref_destination_location
# Out:
#            Entity Code  Year  #refugees_destination
# 8     Afghanistan  AFG  2001                     10
# 9     Afghanistan  AFG  2003                     24
# 10    Afghanistan  AFG  2004                     31
# 11    Afghanistan  AFG  2005                     31
# 12    Afghanistan  AFG  2006                     34
# ...           ...  ...   ...                    ...
# 7395     Zimbabwe  ZWE  2018                   7795
# 7396     Zimbabwe  ZWE  2019                   8956
# 7397     Zimbabwe  ZWE  2020                   9261
# 7398     Zimbabwe  ZWE  2021                   9483
# 7399     Zimbabwe  ZWE  2022                  10475
#
# [3944 rows x 4 columns]

# %%
# Merge DataFrames on 'Year' and 'Code'
refugeedestination_worldrisk = pd.merge(ref_destination_location, world_risk_index, on=['Year', 'Code'], how='inner')
refugeedestination_worldrisk
# Out:
#            Entity Code  Year  #refugees_destination      Country     W     E  \
# 0     Afghanistan  AFG  2003                     24  Afghanistan  4.22  0.25
# 1     Afghanistan  AFG  2004                     31  Afghanistan  4.20  0.25
# 2     Afghanistan  AFG  2005                     31  Afghanistan  4.12  0.25
# 3     Afghanistan  AFG  2006                     34  Afghanistan  4.14  0.25
# 4     Afghanistan  AFG  2007                     43  Afghanistan  4.17  0.25
# ...           ...  ...   ...                    ...          ...   ...   ...
# 3092     Zimbabwe  ZWE  2018                   7795     Zimbabwe  2.50  0.20
# 3093     Zimbabwe  ZWE  2019                   8956     Zimbabwe  2.55  0.20
# 3094     Zimbabwe  ZWE  2020                   9261     Zimbabwe  2.54  0.20
# 3095     Zimbabwe  ZWE  2021                   9483     Zimbabwe  2.53  0.20
# 3096     Zimbabwe  ZWE  2022                  10475     Zimbabwe  2.52  0.20
#
#           V      S      C  ...  AI_04a_Norm  AI_04a_Base  AI_04b_Norm  \
# 0     71.17  62.53  74.70  ...        77.27           41        83.88
# 1     70.48  63.15  73.40  ...        72.62           50        71.58
# 2     67.94  62.22  69.49  ...        71.87           58        71.73
# 3     68.48  61.59  75.41  ...        71.07           58        71.09
# 4     69.62  61.97  76.98  ...        70.00           63        69.70
# ...     ...    ...    ...  ...          ...          ...          ...
# 3092  31.27  30.67  15.24  ...        44.93           89        43.43
# 3093  32.58  32.41  15.45  ...        43.26           90        41.92
# 3094  32.23  31.81  15.39  ...        44.29           86        43.58
# 3095  32.04  31.69  15.34  ...        43.86           86        43.35
# 3096  31.73  31.54  14.88  ...        43.86           86        43.35
#
#       AI_04b_Base  AI_04c_Norm  AI_04c_Base  AI_05a_Norm  AI_05a_Base  \
# 0              41        92.14            6        69.97       252.88
# 1              50       100.00            2        73.91       184.09
# 2              58       100.00            9        73.35       203.37
# 3              58        86.07           18        77.87       179.24
# 4              63       100.00            4        77.87       200.60
# ...           ...          ...          ...          ...          ...
# 3092           89        45.21           78        81.55       271.45
# 3093           90        51.49           75        82.72       245.70
# 3094           86        49.38           74        84.04       210.90
# 3095           86        48.28           74        82.72       288.13
# 3096           86        48.28           74        82.72       288.13
#
#       AI_05b_Norm  AI_05b_Base
# 0           86.91         35.7
# 1           77.87         16.4
# 2           67.55         10.6
# 3           56.41          6.8
# 4           62.88          8.7
# ...           ...          ...
# 3092        70.58         10.6
# 3093        93.27        255.3
# 3094        92.64        557.2
# 3095        89.84         98.5
# 3096        93.27        193.4
#
# [3097 rows x 249 columns]

# %%
refugeedestination_worldrisk = refugeedestination_worldrisk.drop(columns=['Entity'])

# %%
len(refugeedestination_worldrisk.Country.unique())
# Out:
# 173

# %%
len(refugeeorigin_worldrisk.Country.unique())
# Out:
# 191

# %%
refugeedestination_worldrisk.to_csv('refugeedestination_worldrisk.csv',index=False)

# %% [markdown]
# # Data prep with geo data

# %%
geo_worldriskindex = gpd.read_file('worldriskindex_trend.gpkg')
geo_worldriskindex = geo_worldriskindex.rename(columns={'ISO':'Code'})
geo_worldriskindex
# Out:
#     Code  WRI.Country  Year      W      E      V      S      C      A   S_01  \
# 0    ABW         None  None   None   None   None   None   None   None   None
# 1    AFG  Afghanistan  2000   4.25   0.25  72.41   64.2  78.17  75.65  71.25
# 2    AGO       Angola  2000  10.99   2.18  55.44  35.59  62.75  76.28  61.34
# 3    AIA         None  None   None   None   None   None   None   None   None
# 4    ALB      Albania  2000   6.55   2.38     18  12.72  44.07   10.4  51.82
# ..   ...          ...   ...    ...    ...    ...    ...    ...    ...    ...
# 241  CYP       Cyprus  2000   3.73      1  13.89   8.87   8.07  37.44  40.32
# 242  ITA        Italy  2000  10.63   8.85  12.78   8.76   7.56  31.49     29
# 243  ISR       Israel  2000   4.59   0.88  23.93  14.31  31.31  30.59  30.67
# 244  SRB       Serbia  2000   1.95   0.17  22.35  19.19  12.86  45.24  56.21
# 245  CHN        China  2000  39.76  64.32  24.58  25.07  13.76  43.04  48.08
#
#      ... AI_04a_Base AI_04b_Norm AI_04b_Base AI_04c_Norm AI_04c_Base  \
# 0    ...        None        None        None        None        None
# 1    ...          24       91.54          24         100           5
# 2    ...          31         100          21       74.69          21
# 3    ...        None        None        None        None        None
# 4    ...          97       19.81          97       27.05          91
# ..   ...         ...         ...         ...         ...         ...
# 241  ...          97       19.81          97       34.79          85
# 242  ...          87       19.81          97       34.79          85
# 243  ...          93       32.15          93       19.99          95
# 244  ...          95       13.11          98       43.09          78
# 245  ...          85       42.01          86       44.42          75
#
#     AI_05a_Norm AI_05a_Base AI_05b_Norm AI_05b_Base  \
# 0          None        None        None        None
# 1         81.55       85.47       70.41       14.53
# 2         56.16       751.9       93.27         325
# 3          None        None        None        None
# 4         49.54     1232.02        0.01           0
# ..          ...         ...         ...         ...
# 241       37.12     3129.75       53.86         4.9
# 242       32.45      5613.1       42.34         2.6
# 243       30.03     6141.31       30.88         1.1
# 244       56.41      734.53       85.59          70
# 245       53.03      950.36       18.45         0.4
#
#                                               geometry
# 0    MULTIPOLYGON (((-69.97820 12.46986, -70.06292 ...
# 1    MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 2    MULTIPOLYGON (((12.00986 -5.03066, 12.17323 -4...
# 3    MULTIPOLYGON (((-63.06847 18.23680, -63.00681 ...
# 4    MULTIPOLYGON (((19.37540 41.85014, 19.34141 41...
# ..                                                 ...
# 241  MULTIPOLYGON (((33.89257 34.95486, 33.79900 35...
# 242  MULTIPOLYGON (((12.47319 37.73653, 12.42403 37...
# 243  MULTIPOLYGON (((34.22903 31.33431, 34.45208 31...
# 244  MULTIPOLYGON (((20.03311 42.54832, 20.07159 42...
# 245  MULTIPOLYGON (((107.99166 21.54632, 107.81551 ...
#
# [246 rows x 249 columns]

# %%
geoworld_originref = pd.merge(refugeeorigin_worldrisk, geo_worldriskindex[['Code', 'geometry']], on='Code', how='inner')
geoworld_originref = gpd.GeoDataFrame(geoworld_originref, geometry='geometry')
geoworld_originref
# Out:
#           Country Code  Year  #refugees_origin     W     E      V      S  \
# 0     Afghanistan  AFG  2003           2136039  4.22  0.25  71.17  62.53
# 1     Afghanistan  AFG  2004           2414460  4.20  0.25  70.48  63.15
# 2     Afghanistan  AFG  2005           2166139  4.12  0.25  67.94  62.22
# 3     Afghanistan  AFG  2006           2107510  4.14  0.25  68.48  61.59
# 4     Afghanistan  AFG  2007           3057655  4.17  0.25  69.62  61.97
# ...           ...  ...   ...               ...   ...   ...    ...    ...
# 3562     Zimbabwe  ZWE  2018             15618  2.50  0.20  31.27  30.67
# 3563     Zimbabwe  ZWE  2019             10045  2.55  0.20  32.58  32.41
# 3564     Zimbabwe  ZWE  2020              8575  2.54  0.20  32.23  31.81
# 3565     Zimbabwe  ZWE  2021              8115  2.53  0.20  32.04  31.69
# 3566     Zimbabwe  ZWE  2022              7008  2.52  0.20  31.73  31.54
#
#           C      A  ...  AI_04a_Base  AI_04b_Norm  AI_04b_Base  AI_04c_Norm  \
# 0     74.70  77.17  ...           41        83.88           41        92.14
# 1     73.40  75.53  ...           50        71.58           50       100.00
# 2     69.49  72.54  ...           58        71.73           58       100.00
# 3     75.41  69.13  ...           58        71.09           58        86.07
# 4     76.98  70.73  ...           63        69.70           63       100.00
# ...     ...    ...  ...          ...          ...          ...          ...
# 3562  15.24  65.41  ...           89        43.43           89        45.21
# 3563  15.45  69.09  ...           90        41.92           90        51.49
# 3564  15.39  68.36  ...           86        43.58           86        49.38
# 3565  15.34  67.64  ...           86        43.35           86        48.28
# 3566  14.88  68.08  ...           86        43.35           86        48.28
#
#       AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  AI_05b_Base  \
# 0               6        69.97       252.88        86.91         35.7
# 1               2        73.91       184.09        77.87         16.4
# 2               9        73.35       203.37        67.55         10.6
# 3              18        77.87       179.24        56.41          6.8
# 4               4        77.87       200.60        62.88          8.7
# ...           ...          ...          ...          ...          ...
# 3562           78        81.55       271.45        70.58         10.6
# 3563           75        82.72       245.70        93.27        255.3
# 3564           74        84.04       210.90        92.64        557.2
# 3565           74        82.72       288.13        89.84         98.5
# 3566           74        82.72       288.13        93.27        193.4
#
#                                                geometry
# 0     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 1     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 2     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 3     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 4     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# ...                                                 ...
# 3562  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3563  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3564  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3565  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3566  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
#
# [3567 rows x 249 columns]

# %%
geoworld_originref.to_csv('geoworld_originref.csv',index=False)

# %%
geoworld_destinationref = pd.merge(refugeedestination_worldrisk, geo_worldriskindex[['Code', 'geometry']], on='Code', how='inner')
geoworld_destinationref = gpd.GeoDataFrame(geoworld_destinationref, geometry='geometry')
geoworld_destinationref
# Out:
#      Code  Year  #refugees_destination      Country     W     E      V      S  \
# 0     AFG  2003                     24  Afghanistan  4.22  0.25  71.17  62.53
# 1     AFG  2004                     31  Afghanistan  4.20  0.25  70.48  63.15
# 2     AFG  2005                     31  Afghanistan  4.12  0.25  67.94  62.22
# 3     AFG  2006                     34  Afghanistan  4.14  0.25  68.48  61.59
# 4     AFG  2007                     43  Afghanistan  4.17  0.25  69.62  61.97
# ...   ...   ...                    ...          ...   ...   ...    ...    ...
# 3092  ZWE  2018                   7795     Zimbabwe  2.50  0.20  31.27  30.67
# 3093  ZWE  2019                   8956     Zimbabwe  2.55  0.20  32.58  32.41
# 3094  ZWE  2020                   9261     Zimbabwe  2.54  0.20  32.23  31.81
# 3095  ZWE  2021                   9483     Zimbabwe  2.53  0.20  32.04  31.69
# 3096  ZWE  2022                  10475     Zimbabwe  2.52  0.20  31.73  31.54
#
#           C      A  ...  AI_04a_Base  AI_04b_Norm  AI_04b_Base  AI_04c_Norm  \
# 0     74.70  77.17  ...           41        83.88           41        92.14
# 1     73.40  75.53  ...           50        71.58           50       100.00
# 2     69.49  72.54  ...           58        71.73           58       100.00
# 3     75.41  69.13  ...           58        71.09           58        86.07
# 4     76.98  70.73  ...           63        69.70           63       100.00
# ...     ...    ...  ...          ...          ...          ...          ...
# 3092  15.24  65.41  ...           89        43.43           89        45.21
# 3093  15.45  69.09  ...           90        41.92           90        51.49
# 3094  15.39  68.36  ...           86        43.58           86        49.38
# 3095  15.34  67.64  ...           86        43.35           86        48.28
# 3096  14.88  68.08  ...           86        43.35           86        48.28
#
#       AI_04c_Base  AI_05a_Norm  AI_05a_Base  AI_05b_Norm  AI_05b_Base  \
# 0               6        69.97       252.88        86.91         35.7
# 1               2        73.91       184.09        77.87         16.4
# 2               9        73.35       203.37        67.55         10.6
# 3              18        77.87       179.24        56.41          6.8
# 4               4        77.87       200.60        62.88          8.7
# ...           ...          ...          ...          ...          ...
# 3092           78        81.55       271.45        70.58         10.6
# 3093           75        82.72       245.70        93.27        255.3
# 3094           74        84.04       210.90        92.64        557.2
# 3095           74        82.72       288.13        89.84         98.5
# 3096           74        82.72       288.13        93.27        193.4
#
#                                                geometry
# 0     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 1     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 2     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 3     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# 4     MULTIPOLYGON (((60.89944 29.83750, 60.86578 29...
# ...                                                 ...
# 3092  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3093  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3094  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3095  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
# 3096  MULTIPOLYGON (((29.36831 -22.19781, 29.24846 -...
#
# [3097 rows x 249 columns]

# %%
type(geoworld_destinationref)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
geoworld_destinationref.to_csv('geoworld_destinationref.csv',index=False)
